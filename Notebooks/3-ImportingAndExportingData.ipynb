# %%
import pandas as pd

# %% [markdown]
# ### Read csv file

# %%
df2 = pd.read_csv('datasets/housing.csv')

# %%
df2.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# ### read file and specify row 1 has no column names

# %%
df2 = pd.read_csv('datasets/housing.csv', header = None)

# %%
df2
# Out:
#                0         1                   2            3               4  \
# 0      longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 1        -122.23     37.88                41.0        880.0           129.0
# 2        -122.22     37.86                21.0       7099.0          1106.0
# 3        -122.24     37.85                52.0       1467.0           190.0
# 4        -122.25     37.85                52.0       1274.0           235.0
# ...          ...       ...                 ...          ...             ...
# 20636    -121.09     39.48                25.0       1665.0           374.0
# 20637    -121.21     39.49                18.0        697.0           150.0
# 20638    -121.22     39.43                17.0       2254.0           485.0
# 20639    -121.32     39.43                18.0       1860.0           409.0
# 20640    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# ### read file and specify row 1 has column names

# %%
df2 = pd.read_csv('datasets/housing.csv', header = 0)

# %%
df2
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# ### Specify column names

# %%
df2 = pd.read_csv('datasets/housing.csv', names=['Long', 'Lat', 'Median_Age', 'Rooms', 'Bedrooms', 'Population', 'Number_of_Households', 'MedianIncome'])
df2
# Out:
#                                   Long          Lat      Median_Age  \
# longitude latitude  housing_median_age  total_rooms  total_bedrooms
# -122.23   37.88                   41.0        880.0           129.0
# -122.22   37.86                   21.0       7099.0          1106.0
# -122.24   37.85                   52.0       1467.0           190.0
# -122.25   37.85                   52.0       1274.0           235.0
# ...                                ...          ...             ...
# -121.09   39.48                   25.0       1665.0           374.0
# -121.21   39.49                   18.0        697.0           150.0
# -121.22   39.43                   17.0       2254.0           485.0
# -121.32   39.43                   18.0       1860.0           409.0
# -121.24   39.37                   16.0       2785.0           616.0
#
#                          Rooms    Bedrooms     Population  \
# longitude latitude  population  households  median_income
# ...

# %% [markdown]
# ### use part of data

# %%
df2 = pd.read_csv('datasets/housing.csv', usecols=[1,2,3])

# %%
df2
# Out:
#        latitude  housing_median_age  total_rooms
# 0         37.88                41.0        880.0
# 1         37.86                21.0       7099.0
# 2         37.85                52.0       1467.0
# 3         37.85                52.0       1274.0
# 4         37.85                52.0       1627.0
# ...         ...                 ...          ...
# 20635     39.48                25.0       1665.0
# 20636     39.49                18.0        697.0
# 20637     39.43                17.0       2254.0
# 20638     39.43                18.0       1860.0
# 20639     39.37                16.0       2785.0
#
# [20640 rows x 3 columns]

# %% [markdown]
# ### Reading from Url

# %%
iris = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')

# %% [markdown]
# ### Check head

# %%
iris.head(3)
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa

# %% [markdown]
# ### Use cols and index column

# %%
df3 = pd.read_csv('datasets/students.csv', usecols=['ID', 'mark1'], index_col=['ID'])

# %%
df3
# Out:
#     mark1
# ID
# 1    17.0
# 2    24.0
# 3    17.0
# 4    27.0
# 5    30.0
# 6    30.0
# 7    23.0
# 8    17.0
# 9    21.0
# 10   24.0
# 11   24.0
# 12   25.0
# 13   24.0
# 14    NaN
# 15   22.0
# 16   30.0
# 17   29.0
# 18   29.0
# 19    NaN

# %% [markdown]
# ### Pandas can read excel files #need to install xlrd using pip

# %%
df4 = pd.read_excel('datasets/students.xlsx')

# %%
df4
# Out:
#     Unnamed: 0  ID gender  subject  mark1  mark2  mark3 fres
# 0            1   1      M        1   17.0   20.0   15.0  neg
# 1            2   2      F        2   24.0   30.0   23.0  pos
# 2            3   3      F        1   17.0   16.0    NaN  neg
# 3            4   4      M        3   27.0   23.0   21.0  pos
# 4            5   5      M        2   30.0   22.0   24.0  pos
# 5            6   6      F        1   30.0   21.0   25.0  pos
# 6            7   7      M        2   23.0   24.0   24.0  pos
# 7            8   8      F        3   17.0    NaN   20.0  neg
# 8            9   9      M        1   21.0   24.0   24.0  pos
# 9           10  10      F        2   24.0   25.0   24.0  pos
# 10          11  11      F        2   24.0   22.0   25.0  pos
# 11          12  12      M        1   25.0   27.0   24.0  pos
# 12          13  13      F        2   24.0   24.0   25.0  pos
# 13          14  14      M        3    NaN   17.0   15.0  neg
# ...

# %% [markdown]
# ### Working with Json Files

# %%
import numpy as np
jf = pd.DataFrame(np.arange(16).reshape(4, 4), index = ['A', 'B', 'C', 'D'], columns=['var1', 'var2', 'var3', 'var4'])

# %%
jf
# Out:
#    var1  var2  var3  var4
# A     0     1     2     3
# B     4     5     6     7
# C     8     9    10    11
# D    12    13    14    15

# %% [markdown]
# ### write json

# %%
jf.to_json('jf.json')
